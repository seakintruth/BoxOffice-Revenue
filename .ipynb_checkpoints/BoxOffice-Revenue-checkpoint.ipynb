# %% [markdown]
# ## BoxOffice-Revenue
# by Hans Voll
#
# This in an ongoing project intended to accurately predict box office revenue before the release date. This will involve data cleaning, exploration and visualization, and machine learning. The source data for this analysis is located as a dataset on the Kaggle website, and is titled "The Movies" by Rounak Banik. https://www.kaggle.com/rounakbanik/the-movies-dataset

# %% [markdown]
# ### Preprocessing Checklist
# - [ ] Read and format data
# - [ ] Split validation and training sets
# - [ ] Process null values
# - [ ] Encode categorical data
# - [ ] Build model
# - [ ] ...

# %%
# !ls
# Out:
# BoxOffice-Revenue.ipynb Untitled.ipynb
# README.md               movies_metadata.csv

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('movies_metadata.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# status                   45379 non-null object
# tagline                  20412 non-null object
# title                    45460 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('movies_metadata.csv')

def isnumber(x):
    try:
        float(x)
        return True
    except:
        return False

df = df[df.applymap(isnumber)]

df.head()
df["budget"] = pd.to_numeric(df["budget"])
#pd.to_numeric(df['budget'])

df.info()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    0 non-null object
# belongs_to_collection    3 non-null object
# budget                   45463 non-null float64
# genres                   0 non-null object
# homepage                 0 non-null object
# id                       45463 non-null object
# imdb_id                  3 non-null object
# original_language        3 non-null object
# original_title           55 non-null object
# overview                 0 non-null object
# popularity               45460 non-null object
# poster_path              0 non-null object
# production_companies     0 non-null object
# production_countries     3 non-null object
# release_date             3 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         0 non-null object
# status                   0 non-null object
# tagline                  1 non-null object
# title                    57 non-null object
# video                    45460 non-null object
# vote_average             45460 non-null float64
# vote_count               45460 non-null float64
# dtypes: float64(5), object(19)
# memory usage: 8.3+ MB

# %%
import numpy as np
import pandas as pd

dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
dfOrig = pd.read_csv('movies_metadata.csv', parse_dates=['release_date'], date_parser=dateparse)



#df = pd.read_csv(infile, parse_dates=['datetime'], date_parser=dateparse)
    
    #na_values = ['[]', '0'], dtype={'budget':float}, parse_dates=['release_date']).info()
#dfOrig[0]
#, dtype={'budget': float})
'''print("original data:")
print(dfOrig.dtypes)
print(dfOrig.shape)
dfOrig.head()'''
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3177                 result = tools.to_datetime(
# -> 3178                     date_parser(*date_cols), errors='ignore')
#    3179                 if isinstance(result, datetime.datetime):
#
# <ipython-input-46-d9027de59d0d> in <lambda>(x)
#       3
# ----> 4 dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
#       5 dfOrig = pd.read_csv('movies_metadata.csv', parse_dates=['release_date'], date_parser=dateparse)
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3186                                                 parser=date_parser,
# -> 3187                                                 dayfirst=dayfirst),
#    3188                         errors='ignore')
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-46-d9027de59d0d> in <lambda>(x)
#       3
# ----> 4 dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
#       5 dfOrig = pd.read_csv('movies_metadata.csv', parse_dates=['release_date'], date_parser=dateparse)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data 'nan' does not match format '%Y-%m-%d'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d9027de59d0d> in <module>()
#       3
#       4 dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
# ----> 5 dfOrig = pd.read_csv('movies_metadata.csv', parse_dates=['release_date'], date_parser=dateparse)
#       6
#       7
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2066             data = {k: v for k, (i, v) in zip(names, data)}
#    2067
# -> 2068             names, data = self._do_date_conversions(names, data)
#    2069             index, names = self._make_index(data, alldata, names)
#    2070
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _do_date_conversions(self, names, data)
#    1818             data, names = _process_date_conversion(
#    1819                 data, self._date_conv, self.parse_dates, self.index_col,
# -> 1820                 self.index_names, names, keep_date_col=self.keep_date_col)
#    1821
#    1822         return names, data
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3221                 if _isindex(colspec):
#    3222                     continue
# -> 3223                 data_dict[colspec] = converter(data_dict[colspec])
#    3224             else:
#    3225                 new_name, col, old_names = _try_convert_dates(
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in converter(*date_cols)
#    3188                         errors='ignore')
#    3189                 except Exception:
# -> 3190                     return generic_parser(date_parser, *date_cols)
#    3191
#    3192     return converter
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/date_converters.py in generic_parser(parse_func, *cols)
#      38     for i in range(N):
#      39         args = [c[i] for c in cols]
# ---> 40         results[i] = parse_func(*args)
#      41
#      42     return results
#
# <ipython-input-46-d9027de59d0d> in <lambda>(x)
#       2 import pandas as pd
#       3
# ----> 4 dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
#       5 dfOrig = pd.read_csv('movies_metadata.csv', parse_dates=['release_date'], date_parser=dateparse)
#       6
#
# TypeError: strptime() argument 1 must be str, not float

# %%
#Select needed columns to reduce DataFrame size
df = dfOrig[['title','revenue','genres','budget','runtime','release_date','popularity','vote_count','vote_average']]
print("selected data:")
print(df.dtypes)
dfInt.isnull()==True
# Out:
# selected data:
# title            object
# revenue         float64
# genres           object
# budget           object
# runtime         float64
# release_date     object
# popularity       object
# vote_count      float64
# vote_average    float64
# dtype: object
#        title  revenue  genres  budget  runtime  release_date  popularity  \
# 0      False    False   False   False    False         False       False
# 1      False    False   False   False    False         False       False
# 2      False    False   False   False    False         False       False
# 3      False    False   False   False    False         False       False
# 4      False    False   False   False    False         False       False
# 5      False    False   False   False    False         False       False
# 6      False    False   False   False    False         False       False
# 7      False    False   False   False    False         False       False
# 8      False    False   False   False    False         False       False
# 9      False    False   False   False    False         False       False
# 10     False    False   False   False    False         False       False
# 11     False    False   False   False    False         False       False
# 12     False    False   False   False    False         False       False
# 13     False    False   False   False    False         False       False
# 14     False    False   False   False    False         False       False
# 15     False    False   False   False    False         False       False
# 16     False    False   False   False    False         False       False
# 17     False    False   False   False    False         False       False
# 18     False    False   False   False    False         False       False
# 19     False    False   False   False    False         False       False
# 20     False    False   False   False    False         False       False
# 21     False    False   False   False    False         False       False
# 22     False    False   False   False    False         False       False
# 23     False    False   False   False    False         False       False
# 24     False    False   False   False    False         False       False
# 25     False    False   False   False    False         False       False
# 26     False    False   False   False    False         False       False
# 27     False    False   False   False    False         False       False
# 28     False    False   False   False    False         False       False
# 29     False    False   False   False    False         False       False
# ...      ...      ...     ...     ...      ...           ...         ...
# 45436  False    False   False   False    False         False       False
# 45437  False    False   False   False    False         False       False
# 45438  False    False   False   False    False         False       False
# 45439  False    False   False   False    False         False       False
# 45440  False    False   False   False    False         False       False
# 45441  False    False   False   False    False         False       False
# 45442  False    False    True   False    False         False       False
# 45443  False    False   False   False    False         False       False
# 45444  False    False   False   False    False         False       False
# 45445  False    False   False   False    False         False       False
# 45446  False    False   False   False    False         False       False
# 45447  False    False    True   False    False         False       False
# 45448  False    False    True   False    False         False       False
# 45449  False    False   False   False    False         False       False
# 45450  False    False   False   False    False         False       False
# 45451  False    False   False   False    False         False       False
# 45452  False    False   False   False    False         False       False
# 45453  False    False   False   False    False         False       False
# 45454  False    False   False   False    False         False       False
# 45455  False    False    True   False    False         False       False
# 45456  False    False   False   False    False         False       False
# 45457  False    False   False   False    False         False       False
# 45458  False    False   False   False    False         False       False
# 45459  False    False   False   False    False         False       False
# 45460  False    False   False   False    False         False       False
# 45461  False    False   False   False    False          True       False
# 45462  False    False   False   False    False         False       False
# 45463  False    False   False   False    False         False       False
# 45464  False    False    True   False    False         False       False
# 45465  False    False    True   False    False         False       False
#
#        vote_count  vote_average
# 0           False         False
# 1           False         False
# 2           False         False
# 3           False         False
# 4           False         False
# 5           False         False
# 6           False         False
# 7           False         False
# 8           False         False
# 9           False         False
# 10          False         False
# 11          False         False
# 12          False         False
# 13          False         False
# 14          False         False
# 15          False         False
# 16          False         False
# 17          False         False
# 18          False         False
# 19          False         False
# 20          False         False
# 21          False         False
# 22          False         False
# 23          False         False
# 24          False         False
# 25          False         False
# 26          False         False
# 27          False         False
# 28          False         False
# 29          False         False
# ...           ...           ...
# 45436       False         False
# 45437       False         False
# 45438       False         False
# 45439       False         False
# 45440       False         False
# 45441       False         False
# 45442       False         False
# 45443       False         False
# 45444       False         False
# 45445       False         False
# 45446       False         False
# 45447       False         False
# 45448       False         False
# 45449       False         False
# 45450       False         False
# 45451       False         False
# 45452       False         False
# 45453       False         False
# 45454       False         False
# 45455       False         False
# 45456       False         False
# 45457       False         False
# 45458       False         False
# 45459       False         False
# 45460       False         False
# 45461       False         False
# 45462       False         False
# 45463       False         False
# 45464       False         False
# 45465       False         False
#
# [45466 rows x 9 columns]

# %%
#Format date from a string to a dateTime data type 
print("originial time format:")
print(type(df['release_date'][0]))
print(df['release_date'][0])

df['release_date'] = pd.to_datetime(df['release_date'], errors="ignore")
print("fixed time format:")
print(type(df['release_date'][0]))
# Out:
# originial time format:
# <class 'str'>
# 1995-10-30
# fixed time format:
# <class 'str'>
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Fix 'genres' data type: convert stringified JSON object with multiple values, to a single value string 
from pandas.io.json import json_normalize
import ast

for i in range(100):
    x = df['genres'][i]
    if x == '[]':            #if there is no value,
        x = '[{\'id\':0,\'name\':\'NotListed\'}]' #enter 'NotListed' as a placeholder
    x = ast.literal_eval(x)  #convert stringified list of dictionaries to a list of dictionaries
    x = json_normalize(x)    #convert list of dictionaries (in JSON format) into a flat table
    x = x.loc[0, 'name']         #select first value under 'name' column
    df.loc[i, 'genres'] = x    #replace stringified JSON object with selected value

df.head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                          title      revenue     genres    budget  runtime  \
# 0                    Toy Story  373554033.0  Animation  30000000     81.0
# 1                      Jumanji  262797249.0  Adventure  65000000    104.0
# 2             Grumpier Old Men          0.0    Romance         0    101.0
# 3            Waiting to Exhale   81452156.0     Comedy  16000000    127.0
# 4  Father of the Bride Part II   76578911.0     Comedy         0    106.0
#
#   release_date popularity  vote_count  vote_average
# 0   1995-10-30    21.9469      5415.0           7.7
# 1   1995-12-15    17.0155      2413.0           6.9
# 2   1995-12-22    11.7129        92.0           6.5
# 3   1995-12-22    3.85949        34.0           6.1
# 4   1995-02-10    8.38752       173.0           5.7

# %%
#Filter out values that don't apply
print("original shape:")
print(df.shape)

df = df.dropna()
print("after dropping NaN values:")
print(df.shape)

df = df[df.revenue > 1000000]
print("after dropping low revenue values:")
print(df.shape)

df = df[df.budget > 100000]
print("after dropping low budget values:")
print(df.shape)
# Out:
# original shape:
# (45466, 9)
# after dropping NaN values:
# (45130, 9)
# after dropping low revenue values:
# (6052, 9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9de15f07d55f> in <module>()
#      11 print(df.shape)
#      12
# ---> 13 df = df[df.budget > 100000]
#      14 print("after dropping low budget values:")
#      15 print(df.shape)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1601         result = libops.vec_compare(x, y, op)
#    1602     else:
# -> 1603         result = libops.scalar_compare(x, y, op)
#    1604     return result
#    1605
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ##Explore data with various graphs

# %%
from matplotlib import pyplot as plt
import seaborn as sns

#sns.set()
#plt.figure(figsize=(15,5))
#plt.xlim(1990-01-13,2017-01-01)
#sns.scatterplot(x='release_date', y='revenue', data = df)


#plt.show()

# %%
df.sort_values(by=['revenue'],ascending=False).head(40)

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.scatterplot(x='budget', y='revenue', data = df)

plt.show()

# %%
df.sort_values(by=['budget'], ascending=False).head(40)

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.regplot(x='vote_average', y='revenue', data = df)

plt.show()

# %%
df.sort_values(by=['vote_average'],ascending=False).head(40)

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.scatterplot(x='popularity', y='revenue', data = df)
plt.xlim(0, 40)
plt.show()

# %%
df.sort_values(by=['popularity'],ascending=False).head(40)

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.scatterplot(x='runtime', y='revenue', data = df)
plt.xlim(50,200)
plt.show()

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.regplot(x='vote_count', y='revenue', data = df)

plt.show()

# %%
df.sort_values(by=['vote_count'],ascending=False).head(40)

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.regplot(x='vote_count', y='vote_average', data = df)

plt.show()

# %%
sns.set()
plt.figure(figsize=(15,5))
sns.scatterplot(x='vote_count', y='popularity', data = df)

plt.show()

# %%
y = df.revenue
features = ['vote_count','revenue','runtime']
X = df[features]

# %%
from sklearn.tree import DecisionTreeRegressor
revenue_model = DecisionTreeRegressor(random_state=1)
revenue_model.fit(X, y)

# %%
print("predicting first 25 movies:")
print(X.head(25))
print("Predictions are $$$..")
print(revenue_model.predict(X.head(25)))

# %%
df['title'].head(25)

# %%
#Calculate mean absolute error (MAE) without splitting into training and validation data
from sklearn.metrics import mean_absolute_error

predicted_revenue = revenue_model.predict(X)
mean_absolute_error(y, predicted_revenue)

# %%
#Split into training('train_') and validation('val_') data, then recalculate MAE.
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
revenue_model = DecisionTreeRegressor()
revenue_model.fit(train_X, train_y)
val_predictions = revenue_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))

# %%
dfOrig.head()
